# %%
# %pylab inline
from ipywidgets import widgets
import mpld3
mpld3.enable_notebook()
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Read results from Carbon Portal database

# %% [markdown]
# In this step all inversion results currently available at the CP, are imported into this notebook.
# In the future, this will have a more advanced interface with the actual CP.

# %%
from read_from_CP import *

# %% [markdown]
# # Plot fossil fuel emissions, used as input in the inversions

# %%
widgets.interact(fig_ff, Jena=False, MACC=False, CTE=False, Temporal_Resolution=(['Monthly','Yearly']))
# Out:
# <function read_from_CP.fig_ff>

# %% [markdown]
# # Plot biosphere fluxes

# %%
widgets.interact(fig_bio, Jena=False, MACC=False, CTE=False, Temporal_Resolution=(['Monthly','Yearly']))

# %% [markdown]
# # Plot ocean fluxes

# %%
MyModel_X=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]
MyModel_Y=[-2.13,-1.99,-2.31,-2.42,-2.30,-2.32,-2.48,-2.50,-2.48,-2.54,-2.52,-2.66,-2.80,-2.81,-2.93]
read_My_Model(MM_X=MyModel_X,MM_Y=MyModel_Y)
widgets.interact(fig_oce, Jena=False, MACC=False, CTE=False, MyModel=False, Temporal_Resolution=(['Monthly','Yearly']))

# %% [markdown]
# # Plot ocean fluxes with GCP results

# %%
widgets.interact(fig_oce_gcp, Data_Based_Products=False, Jena=False, MACC=False, CTE=False)
